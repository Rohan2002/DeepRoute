# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from utils import sharpen_image

# %%
img_p = '/Users/user/Applications/machine-learning/deeproute/data/train/parent_PrL-4-5cb4c947-f79b-4f7f-a633-2b828e65a9fe.jpg'
img=np.array(cv2.imread(img_p))

# %%
plt.imshow(img)
